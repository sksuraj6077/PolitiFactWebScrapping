# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time

authors = []
statements = []
targets = []
text_1 = []
url_1 = []
d = {}

def scrape_website(page_number, category):
    page_num = str(page_number)
    #https://www.politifact.com/factchecks/list/?page=10&category=california
    URL = 'https://www.politifact.com/factchecks/list/?page={}&category={}'.format(page_num, category)
    
    webpage = requests.get(URL) 
    #time.sleep(3)
    soup = BeautifulSoup(webpage.text, "html.parser") #Parse the text from the website
    
    statement_footer =  soup.find_all('footer',attrs={'class':'m-statement__footer'}) 
    statement_quote = soup.find_all('div', attrs={'class':'m-statement__quote'})
    statement_meta = soup.find_all('div', attrs={'class':'m-statement__meta'})
    #statement_text = soup.find_all('div',attrs={'short-on-time'})
    target = soup.find_all('div', attrs={'class':'m-statement__meter'}) 
    for i in statement_footer:
        link1 = i.text.strip()
        name_and_date = link1.split()
        first_name = name_and_date[1]
        last_name = name_and_date[2]
        full_name = first_name+' '+last_name
        authors.append(full_name)


    # for i in statement_quote:
    #     link2 = i.find_all('a')
    #     statements.append(link2[0].text.strip())
    # #for i in statement_text:
    #     link0 = i.find_all('a')
    #     #print(i)
    #     text_1.append(link0[0].text.strip())

    for i in statement_quote:
      for link in i.find_all('a',href=True):
        statements.append(i.text)
        url_1.append("https://www.politifact.com"+link['href'])
    for link1 in url_1:
      webpage1 = requests.get(link1)
      soup1 = BeautifulSoup(webpage1.text, "html.parser") 
      statement_text = soup1.find_all('div',attrs={'short-on-time'})
      text_1.append(statement_text[0].text)
    for x in range(len(statements)):
      d[statements[x]]=text_1[x]



    for i in target:
        fact = i.find('div', attrs={'class':'c-image'}).find('img').get('alt')
        targets.append(fact)

#florida
#california
n=2
for i in range(1, n):
    scrape_website(i, category='illinois')

data = pd.DataFrame(columns = ['Title','Author','Text','Target','Label'])
data['Author'] = authors
data['Title'] = statements
#data['Label'] = 
data['Text'] = d.values()
data['Target'] = targets
print(text_1)
data
#data.iloc[:5].to_csv('politifact-joe-biden-sample.csv', index=False, sep=',')
# Out:
# ['\n\n\nIllinois election officials told PolitiFact that using Sharpie pens to fill out ballots is allowed.\xa0\n\n\nIf a ballot is rendered invalid by a voting machine, that ballot is spoiled and the voter may fill out another.\n\n\n', '\n\n\nA law that eliminates cash bail in Illinois will go into effect Jan. 1. It removes money as a factor in determining whether a suspect can be released while awaiting trial.\xa0\n\n\nThe new law did not create “nondetainable” offenses. Prosecutors can still petition judges to detain suspects, and must provide evidence to prove the suspects are a public safety threat or flight risk.\n\n\nAll of the crimes listed in a Facebook post could result in a suspect being detained until trial.\n\n\n', '\n\nAdam Kinzinger said Trump had won the “Trump versus Kinzinger war” over the soul of the Republican Party. He didn’t say Trump won the election.\xa0\xa0\n\n\xa0\n', '\n\nR. Kelly didn’t escape prison. He was recently moved from a federal detention facility in New York to one in Chicago where he awaits another criminal trial.\xa0\n\n\xa0\n', '\n\n\nRobert Crimo III, who opened fire during an Independence Day celebration in Highland Park, Illinois, had a history of encounters with local police, but was not barred from legally purchasing weapons.\n\n\nInvestigators told news outlets that Crimo obtained the proper identification needed to legally purchase firearms and passed several background checks before buying his weapons legally.\n\n\nNeither law enforcement officials nor the shooter’s family members used the state’s red flag law and petitioned to prevent him from acquiring guns.\n\n\n', '\n\n\nNone of the images supposedly pulled from Crimo’s social media feeds have been verified and the evidence supporting their authenticity is thin.\n\n\nScreenshots of Crimo’s supposed Instagram account omitted information, such as a username, that could have been used to verify it.\n\n\n', '\n\nThis claim is baseless. The shooting suspect has confessed, authorities said, and witnesses have told reporters what they saw.\xa0\n\n\xa0\n', '\n\n\nRep. Marjorie Taylor Greene shared an image featuring the Highland Park shooting suspect, falsely claiming it was a photo that showed him “in jail or rehab or a psychiatric center.”\xa0\n\n\nThe image is noticeably edited; one expert said it contains “clear signs of manipulation.”\n\n\n', '\n\n\n\xa0Illinois high school administrators are not grading students based on their race\n\n\nAdministrators are working to develop an approach for equitable grading, though it will rely on objective assessments of whether students have mastered the material.\xa0\n\n\nWest Cook News, the source of this claim,\xa0is part of a group of websites that has taken funding from conservative groups.\n\n\n', '\n\nChicago is frequently targeted as a city with ineffective, strict gun laws. While the city has a history of implementing tougher laws in comparison to other cities, Supreme Court decisions drastically loosened some restrictions.\nThis claim does not take into consideration how loose\xa0gun laws in certain states impact neighboring states with strict laws.\xa0\n\n', '\n\n\xa0In his bid for Congress, Mayor Keith Pekau is touting the downward turn in reported crimes during his tenure. While the reported statistics bear him out, there was a spike in violent crime his first year in office.\n\n', '\n\n\nThe sources Rep. Mary Miller used to back her claim that the White House is encouraging children to take chemical castration drugs and undergo surgeries fall short.\xa0\n\n\nSeveral medical organizations support the use of hormonal treatments for children who — with medical consultation — decide to delay puberty.\xa0\n\n\nMost credible scientific studies show the effects of puberty blockers are reversible.\n\n\n', '\n\nThe U.S. Senator\xa0joins a growing number of Democratic politicians who have incorrectly cited a national study of the gender pay gap to include an analysis of men and women in  ...
#                                                 Title                 Author  \
# 0   \n\n‘No Sharpies on ballots’ permitted for in-...    Michael Majchrowicz
# 1   \n\nUnder new Illinois law, these crimes are “...           Jeff Cercone
# 2   \n\nRep. Adam Kinzinger “admits Trump won” the...         Ciara O'Rourke
# 3   \n\nR. Kelly “missing after prison security ve...         Ciara O'Rourke
# 4   \n\nShooter in Highland Park, Illinois, “bough...         Madison Czopek
# 5   \n\nImages show Highland Park shooter had anti...            Yacob Reyes
# 6   \n\nThe mass shooting in Highland Park, Illino...         Ciara O'Rourke
# 7   \n\nSays an image shows the Highland Park shoo...          Bill McCarthy
# 8   \n\nIllinois high school to implement race-bas...           Jill Terreri
# 9   \n\n"We need to realize that people who think ...       Analisa Trofimuk
# 10  \n\nWe’ve reduced crime to its lowest level in...       Analisa Trofimuk
# 11  \n\nThe Biden Administration is engaging in ex...       Analisa Trofimuk
# 12  \n\n“An extra 2 whole months and 15 days. That...       Analisa Trofimuk
# 13  \n\n"In my first year in office, Aurora homici...       Analisa Trofimuk
# 14  \n\n"There is absolutely no observed or clinic...       Analisa Trofimuk
# 15  \n\n“A larger percentage of Illinoisans have b...       Analisa Trofimuk
# 16  \n\n"Chicago maintained the lowest unemploymen...       Analisa Trofimuk
# 17  \n\nThe migrant caravan from Tapachula, Mexico...  Kiannah Sepeda-Miller
# 18  \n\n“75% of Republicans have been vaccinated” ...  Kiannah Sepeda-Miller
# 19  \n\nSays the 1995 Chicago heat wave was “the l...  Kiannah Sepeda-Miller
# 20  \n\nA slain Chicago police officer left behind...         Ciara O'Rourke
# 21  \n\nHouse Speaker Nancy Pelosi’s “office was c...  Kiannah Sepeda-Miller
# 22  \n\n“You can't actually use ARPA (American Res...  Kiannah Sepeda-Miller
# 23  \n\n“You may be 55 years old in [Illinois] and...  Kiannah Sepeda-Miller
# 24  \n\nCook County’s criminal courts “have been s...  Kiannah Sepeda-Miller
# 25  \n\n“Prairie State power plant is the cleanest...  Kiannah Sepeda-Miller
# 26  \n\nIllinois Republican lawmakers “have argued...  Kiannah Sepeda-Miller
# 27  \n\nOpposition to having a fully elected Chica...  Kiannah Sepeda-Miller
# 28  \n\n“We have 23% of all the lead pipe leads in...  Kiannah Sepeda-Miller
# 29  \n\nThe American Rescue Plan Act “does not” in...  Kiannah Sepeda-Miller
#
#                                                  Text       Target Label
# 0   \n\n\nIllinois election officials told PolitiF...        false   NaN
# 1   \n\n\nA law that eliminates cash bail in Illin...        false   NaN
# 2   \n\nAdam Kinzinger said Trump had won the “Tru...        false   NaN
# 3   \n\nR. Kelly didn’t escape prison. He was rece...        false   NaN
# 4   \n\n\nRobert Crimo III, who opened fire during...        false   NaN
# 5   \n\n\nNone of the images supposedly pulled fro...        false   NaN
# 6   \n\nThis claim is baseless. The shooting suspe...   pants-fire   NaN
# 7   \n\n\nRep. Marjorie Taylor Greene shared an im...        false   NaN
# 8   \n\n\n Illinois high school administrators are...        false   NaN
# 9   \n\nChicago is frequently targeted as a city w...  barely-true   NaN
# 10  \n\n In his bid for Congress, Mayor Keith Peka...         true   NaN
# 11  \n\n\nThe sources Rep. Mary Miller used to bac...        false   NaN
# 12  \n\nThe U.S. Senator joins a growing number of...  barely-true   NaN
# 13  \n\n\nAurora Mayor Richard Irvin in a tweet la...  barely-true   NaN
# 14  \n\nState Rep. Blaine Wilhour said there is ab...  barely-true   NaN
# 15  \n\nGov. Pritzker said “a larger percentage of...  mostly-true   NaN
# 16  \n\nWe compared data from the U.S. Bureau of L...        false   NaN
# 17  \n\n\nMinneapolis has nearly 430,000 residents...   pants-fire   NaN
# 18  \n\nBryant did not respond to our inquiries as...        false   NaN
# 19  \n\n\nChicago's 1995 heat wave spanned multipl...  barely-true   NaN
# 20  \n\nElla French’s brother and the superintende...        false   NaN
# 21  \n\nDavis highlighted the fact that then-House...  barely-true   NaN
# 22  \n\nOn May 17, the U.S. Department of the Trea...        false   NaN
# 23  \n\nLast year, Illinois created a program offe...        false   NaN
# 24  \n\nLast year, the Circuit Court of Cook Count...        false   NaN
# 25  \n\nExperts pointed to multiple metrics by whi...   pants-fire   NaN
# 26  \n\nRepublicans in the Illinois General Assemb...  barely-true   NaN
# 27  \n\n\nMartwick pointed to surveys, non-binding...         true   NaN
# 28  \n\n\nDurbin's office told us he meant to refe...    half-true   NaN
# 29  \n\nThe package allows spending not only on pu...    half-true   NaN

# %%
def getBinaryNumTarget(text):
    if text == 'true':
        return 1
    elif text == 'mostly-true':
        return 1
    else:
        return 0

# %%
data['Label']=data['Target'].apply(getBinaryNumTarget)

# %%
data
# Out:
#                                                 Title                 Author  \
# 0   \n\n‘No Sharpies on ballots’ permitted for in-...    Michael Majchrowicz
# 1   \n\nUnder new Illinois law, these crimes are “...           Jeff Cercone
# 2   \n\nRep. Adam Kinzinger “admits Trump won” the...         Ciara O'Rourke
# 3   \n\nR. Kelly “missing after prison security ve...         Ciara O'Rourke
# 4   \n\nShooter in Highland Park, Illinois, “bough...         Madison Czopek
# 5   \n\nImages show Highland Park shooter had anti...            Yacob Reyes
# 6   \n\nThe mass shooting in Highland Park, Illino...         Ciara O'Rourke
# 7   \n\nSays an image shows the Highland Park shoo...          Bill McCarthy
# 8   \n\nIllinois high school to implement race-bas...           Jill Terreri
# 9   \n\n"We need to realize that people who think ...       Analisa Trofimuk
# 10  \n\nWe’ve reduced crime to its lowest level in...       Analisa Trofimuk
# 11  \n\nThe Biden Administration is engaging in ex...       Analisa Trofimuk
# 12  \n\n“An extra 2 whole months and 15 days. That...       Analisa Trofimuk
# 13  \n\n"In my first year in office, Aurora homici...       Analisa Trofimuk
# 14  \n\n"There is absolutely no observed or clinic...       Analisa Trofimuk
# 15  \n\n“A larger percentage of Illinoisans have b...       Analisa Trofimuk
# 16  \n\n"Chicago maintained the lowest unemploymen...       Analisa Trofimuk
# 17  \n\nThe migrant caravan from Tapachula, Mexico...  Kiannah Sepeda-Miller
# 18  \n\n“75% of Republicans have been vaccinated” ...  Kiannah Sepeda-Miller
# 19  \n\nSays the 1995 Chicago heat wave was “the l...  Kiannah Sepeda-Miller
# 20  \n\nA slain Chicago police officer left behind...         Ciara O'Rourke
# 21  \n\nHouse Speaker Nancy Pelosi’s “office was c...  Kiannah Sepeda-Miller
# 22  \n\n“You can't actually use ARPA (American Res...  Kiannah Sepeda-Miller
# 23  \n\n“You may be 55 years old in [Illinois] and...  Kiannah Sepeda-Miller
# 24  \n\nCook County’s criminal courts “have been s...  Kiannah Sepeda-Miller
# 25  \n\n“Prairie State power plant is the cleanest...  Kiannah Sepeda-Miller
# 26  \n\nIllinois Republican lawmakers “have argued...  Kiannah Sepeda-Miller
# 27  \n\nOpposition to having a fully elected Chica...  Kiannah Sepeda-Miller
# 28  \n\n“We have 23% of all the lead pipe leads in...  Kiannah Sepeda-Miller
# 29  \n\nThe American Rescue Plan Act “does not” in...  Kiannah Sepeda-Miller
#
#                                                  Text       Target  Label
# 0   \n\n\nIllinois election officials told PolitiF...        false      0
# 1   \n\n\nA law that eliminates cash bail in Illin...        false      0
# 2   \n\nAdam Kinzinger said Trump had won the “Tru...        false      0
# 3   \n\nR. Kelly didn’t escape prison. He was rece...        false      0
# 4   \n\n\nRobert Crimo III, who opened fire during...        false      0
# 5   \n\n\nNone of the images supposedly pulled fro...        false      0
# 6   \n\nThis claim is baseless. The shooting suspe...   pants-fire      0
# 7   \n\n\nRep. Marjorie Taylor Greene shared an im...        false      0
# 8   \n\n\n Illinois high school administrators are...        false      0
# 9   \n\nChicago is frequently targeted as a city w...  barely-true      0
# 10  \n\n In his bid for Congress, Mayor Keith Peka...         true      1
# 11  \n\n\nThe sources Rep. Mary Miller used to bac...        false      0
# 12  \n\nThe U.S. Senator joins a growing number of...  barely-true      0
# 13  \n\n\nAurora Mayor Richard Irvin in a tweet la...  barely-true      0
# 14  \n\nState Rep. Blaine Wilhour said there is ab...  barely-true      0
# 15  \n\nGov. Pritzker said “a larger percentage of...  mostly-true      1
# 16  \n\nWe compared data from the U.S. Bureau of L...        false      0
# 17  \n\n\nMinneapolis has nearly 430,000 residents...   pants-fire      0
# 18  \n\nBryant did not respond to our inquiries as...        false      0
# 19  \n\n\nChicago's 1995 heat wave spanned multipl...  barely-true      0
# 20  \n\nElla French’s brother and the superintende...        false      0
# 21  \n\nDavis highlighted the fact that then-House...  barely-true      0
# 22  \n\nOn May 17, the U.S. Department of the Trea...        false      0
# 23  \n\nLast year, Illinois created a program offe...        false      0
# 24  \n\nLast year, the Circuit Court of Cook Count...        false      0
# 25  \n\nExperts pointed to multiple metrics by whi...   pants-fire      0
# 26  \n\nRepublicans in the Illinois General Assemb...  barely-true      0
# 27  \n\n\nMartwick pointed to surveys, non-binding...         true      1
# 28  \n\n\nDurbin's office told us he meant to refe...    half-true      0
# 29  \n\nThe package allows spending not only on pu...    half-true      0
